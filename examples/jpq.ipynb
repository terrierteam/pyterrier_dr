# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyterrier as pt
import pyterrier_dr
import torch

# %%
# %cd ..
# Out:
# /home/nicola/code/pyterrier_dr_jpq
# /home/nicola/miniforge3/envs/pyterrier-dr-jpq/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
#!rm -rf ./flex
tct = pyterrier_dr.TctColBert(device=torch.device("cuda"))
index = pyterrier_dr.FlexIndex("./flex")
#(tct >> index).index(pt.get_dataset("vaswani").get_corpus_iter())

# %%
len(index)
# Out:
# 11429

# %%
import ir_datasets
train_dataset = ir_datasets.load("msmarco-passage/train")

# %%
from pyterrier_dr.jpq import JPQTrainer
t = JPQTrainer(tct, index)
t.fit(train_dataset.docpairs_iter(), queries=train_dataset.queries_iter())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from pyterrier_dr.jpq import JPQTrainer
#       2 t = JPQTrainer(tct, index)
#       3 t.fit(train_dataset.docpairs_iter(), queries=train_dataset.queries_iter())
#
# File ~/code/pyterrier_dr_jpq/pyterrier_dr/jpq/__init__.py:2
#       1 from .index import JPQIndex
# ----> 2 from .train import JPQTrainer
#
# File ~/code/pyterrier_dr_jpq/pyterrier_dr/jpq/train.py:60
#      56         out[i] = vals
#      57     return out
# ---> 60 class JPQTrainer:
#      62     def __init__(
#      63             self,
#      64             existing_model : pyterrier_dr.BiEncoder,
#    (...)
#      68             pq_nbits: int = 8,
#      69             wandb : wandb.Run | NullWanDBRun = NullWanDBRun()):
#      70         super().__init__()
#
# File ~/code/pyterrier_dr_jpq/pyterrier_dr/jpq/train.py:178, in JPQTrainer()
#     166     self._training_loop(self.model, pq, dl, epochs, lr, patience,
#     167                         selected_doc_ids, codes_sel,
#     168                         eval_queries, cut_qrels, recon_batch_size)
#     169     self.fitted = True
#     172 def _dataloader(self,
#     173                 training_docpairs,
#     174                 batch_size : int, # batch size for training
#     175                 selected_doc_ids : list[str], # documents that we're using during training
#     176                 sel_inv : dict[str,int], # map from str docid -> index into codes_sel
#     177                 queries : dict[str,str], # map from str queryid -> query text
# --> 178                 codes_sel : np.array) -> DataLoader: # PQ codes for selected documents
#     179
#     180     # make it a set of easier dataset filtering below
#     181     selected_doc_ids = set(selected_doc_ids)
#     182     # bring codes to torch
#
# NameError: name 'DataLoader' is not defined
