# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pyterrier as pt
import pyterrier_dr
import torch

# %%
# %cd ..
# Out:
# /home/nicola/code
# /home/nicola/miniforge3/envs/pyterrier-dr-jpq/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
#!rm -rf ./flex
tct = pyterrier_dr.TctColBert(device=torch.device("cuda"))
index = pyterrier_dr.FlexIndex("./flex")
#(tct >> index).index(pt.get_dataset("vaswani").get_corpus_iter())

# %%
len(index)
# Out:
# 11429

# %%
import ir_datasets
train_dataset = ir_datasets.load("msmarco-passage/train")

# %%
from pyterrier_dr.jpq import JPQTrainer
t = JPQTrainer(tct, index)
t.fit(train_dataset.docpairs_iter(), queries=train_dataset.queries_iter())
# Out:
# [JPQTrainer] device= cuda
# Ingesting query mapping
# Ingesting docno mapping from index
# [SUBSET] using ALL 11429 docs from index
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 from pyterrier_dr.jpq import JPQTrainer
#       2 t = JPQTrainer(tct, index)
# ----> 3 t.fit(train_dataset.docpairs_iter(), queries=train_dataset.queries_iter())
#
# File ~/code/pyterrier_dr_jpq/pyterrier_dr/jpq/train.py:163, in JPQTrainer.fit(self, training_docpairs, queries, code_batch_size, recon_batch_size, pq_sample_size, docid_subset, epochs, batch_size, patience, extra_neg_pool, eval_queries, eval_qrels, lr)
#     160     cut_qrels = None
#     162 # ------- PQ -------
# --> 163 codes_sel, centroids = self._compute_PQ(pq_sample_size, code_batch_size, sel_indices, vecs_mem, rng)
#     165 # ------- initialise the model -------
# ...
